# %% [markdown]
# ## K mediod Clustering when K=4

# %%
import pandas as pd
import numpy as np
import random 
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from math import*

from scipy.spatial.distance import pdist,squareform

# %%
def manhattan_distance(person1, person2):
    distance = 0
    distance += abs(person1 - person2)
    return distance

# %%
Assigned_cluster = pd.DataFrame(np.zeros((196, 1), dtype=int))

# %%
dataset = pd.read_csv('Mall_Customers.csv')#---------reading dataset
customer = dataset.to_numpy()

# %% [markdown]
# ## calculating Disimilarity MAtrix below

# %%
squareform(pdist(customer[:,2:], metric='euclidean'))#---------calculating dissimilarity matrix
# Out:
# array([[  0.        ,  42.04759208,  33.03028913, ..., 117.1110584 ,
#         124.47489707, 130.15759678],
#        [ 42.04759208,   0.        ,  75.01333215, ..., 111.7631424 ,
#         137.74614332, 122.34786471],
#        [ 33.03028913,  75.01333215,   0.        , ..., 129.87686476,
#         122.18428704, 143.77065069],
#        ...,
#        [117.1110584 , 111.7631424 , 129.87686476, ...,   0.        ,
#          57.07013229,  14.35270009],
#        [124.47489707, 137.74614332, 122.18428704, ...,  57.07013229,
#           0.        ,  65.03076195],
#        [130.15759678, 122.34786471, 143.77065069, ...,  14.35270009,
#          65.03076195,   0.        ]])

# %%
k = 4 #----------------NUMBER OF CLUSTERS

# %% [markdown]
# ## Plotting graph before clustering

# %%
sns.set_style("white")
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(dataset.Age, dataset["Annual Income (k$)"], dataset["Spending Score (1-100)"], c='blue', s=60)
ax.view_init(30, 185)
plt.xlabel("Age")
plt.ylabel("Annual Income (k$)")
ax.set_zlabel('Spending Score (1-100)')
plt.show()

# %%
mediod = customer[np.random.choice(customer.shape[0], k, replace=False), :]#---------randomly choosing mediods

# %%
###*********************                           #----------delete the mediods value from dataset
customer_new = np.delete(customer, (mediod[0,0] - 1, mediod[1,0] - 1, mediod[2,0] - 1, mediod[3,0] - 1), axis=0)#-------need to be changed as the value of k changes
#dataset1 = np.delete(dataset, (mediod[0,0] - 1, mediod[1,0] - 1, mediod[2,0] - 1, mediod[3,0] - 1), axis=0)#-------need to be changed as the value of k changes
dataset_1=dataset.drop(dataset.index[[mediod[0,0] - 1, mediod[1,0] - 1, mediod[2,0] - 1, mediod[3,0] - 1]])

# %%
print(mediod[2, 2])
print(customer.shape)
print(customer_new.shape)
distance_age = 0
distance_income = 0
distance_score = 0
total_distance_cost = np.zeros((len(customer_new),k))
print(total_distance_cost.shape)
print(customer_new.shape)
print(dataset_1.shape)
non_mediod = 0
# Out:
# 19
# (200, 5)
# (196, 5)
# (196, 4)
# (196, 5)
# (196, 5)

# %% [markdown]
# ## Calculating distance between mediod and points and assigning clusters to it

# %%
###************************----------------needs to be modified as the value of k changes
#---------------------------comparing when value of k=1
old_cost = 0
total_cost_cluster = 0
difference_cost=0
for l in range(len(customer_new)):
    
    distance_age_k1 = []
    distance_income_k1 = []
    distance_score_k1 = []
    total_distance_k1 = []
    q=0
    w=0
    e=0
    total=0
    i=0

    for j in range(len(customer_new)):
        q = manhattan_distance(mediod[i,2],customer_new[j,2])
        distance_age_k1.append(q)
        w = manhattan_distance(mediod[i,3],customer_new[j,3])
        distance_income_k1.append(w)
        e = manhattan_distance(mediod[i,4],customer_new[j,4])
        distance_score_k1.append(e)
        total = q+w+e
        total_distance_k1.append(total)

    #---------------------------comparing when value of k=2        

    distance_age_k2 = []
    distance_income_k2 = []
    distance_score_k2 = []
    total_distance_k2 = []
    q=0
    w=0
    e=0
    total=0
    i=1
    for j in range(len(customer_new)):
        q = manhattan_distance(mediod[i,2],customer_new[j,2])
        distance_age_k2.append(q)
        w = manhattan_distance(mediod[i,3],customer_new[j,3])
        distance_income_k2.append(w)
        e = manhattan_distance(mediod[i,4],customer_new[j,4])
        distance_score_k2.append(e)
        total = q+w+e
        total_distance_k2.append(total)

    #---------------------------comparing when value of k=3       
    distance_age_k3 = []
    distance_income_k3 = []
    distance_score_k3 = []
    total_distance_k3 = []
    q=0
    w=0
    e=0
    total=0
    i=2


    for j in range(len(customer_new)):
        q = manhattan_distance(mediod[i,2],customer_new[j,2])
        distance_age_k3.append(q)
        w = manhattan_distance(mediod[i,3],customer_new[j,3])
        distance_income_k3.append(w)
        e = manhattan_distance(mediod[i,4],customer_new[j,4])
        distance_score_k3.append(e)
        total = q+w+e
        total_distance_k3.append(total)


    #---------------------------comparing when value of k=4        
    distance_age_k4 = []
    distance_income_k4 = []
    distance_score_k4 = []
    total_distance_k4 = []
    q=0
    w=0
    e=0
    total=0
    i=3
    for j in range(len(customer_new)):
        q = manhattan_distance(mediod[i,2],customer_new[j,2])
        distance_age_k4.append(q)
        w = manhattan_distance(mediod[i,3],customer_new[j,3])
        distance_income_k4.append(w)
        e = manhattan_distance(mediod[i,4],customer_new[j,4])
        distance_score_k4.append(e)
        total = q+w+e
        total_distance_k4.append(total)        





    cost_1 = pd.DataFrame({'Cost_1':total_distance_k1})
    cost_2 = pd.DataFrame({'Cost_2':total_distance_k2})
    cost_3 = pd.DataFrame({'Cost_3':total_distance_k3})
    cost_4 = pd.DataFrame({'Cost_4':total_distance_k4})


    dataset_1 = dataset_1.assign(cost_1=cost_1.values,cost_2=cost_2.values,cost_3=cost_3.values,cost_4=cost_4.values,Assigned_cluster=Assigned_cluster.values)
   

    customer_new = dataset_1.to_numpy()
    #print(customer_new[0:10, :])#---------------combined dataset which displays cost of all k, the last four coloumns are the cost




    #*************************************
    #----now we will create 4 clusters as the value of k =4 on the basis of total distance or cost


    cluster_1 = []
    cluster_2 = []
    cluster_3 = []
    cluster_4 = []
    q=0
    w=0
    e=0
    r=0
    i=0

    for i in range(len(customer_new)):

        if(customer_new[i][5] <= customer_new[i][6] and customer_new[i][5] <= customer_new[i][7] and customer_new[i][5]<= customer_new[i][8]):
            #print("five")
            q = customer_new[i]
            cluster_1.append(q)
            dataset_1.iloc[i, dataset_1.columns.get_loc('Assigned_cluster')] = "Cluster_1"


        if(customer_new[i][6] <= customer_new[i][5] and customer_new[i][6] <= customer_new[i][7] and customer_new[i][6]<= customer_new[i][8]):
            #print("six")
            w = customer_new[i]
            cluster_2.append(w)
            dataset_1.iloc[i, dataset_1.columns.get_loc('Assigned_cluster')] = "Cluster_2"

        if(customer_new[i][7] <= customer_new[i][6] and customer_new[i][7] <= customer_new[i][5] and customer_new[i][7]<= customer_new[i][8]):
           # print("seven")
            e = customer_new[i]
            cluster_3.append(e)
            dataset_1.iloc[i, dataset_1.columns.get_loc('Assigned_cluster')] = "Cluster_3"

        if(customer_new[i][8] <= customer_new[i][6] and customer_new[i][8] <= customer_new[i][7] and customer_new[i][8]<= customer_new[i][5]):
           # print("eight")
            r = customer_new[i]
            cluster_4.append(r)
            dataset_1.iloc[i, dataset_1.columns.get_loc('Assigned_cluster')] = "Cluster_4"
            
    print("lenth is", + len(cluster_4))
  
    if(len(cluster_4) == 0):
        cluster_4 = cluster_4_old
    if(len(cluster_3) == 0):
        cluster_3 = cluster_3_old
    if(len(cluster_2) == 0):
        cluster_2 = cluster_2_old
    if(len(cluster_1) == 0):
        cluster_1 = cluster_2_old
    total_cost_cluster = 0
    cluster_1 = np.asarray(cluster_1)
    cluster_2 = np.asarray(cluster_2)
    cluster_3 = np.asarray(cluster_3)
    cluster_4 = np.asarray(cluster_4)
    sum_cluster_1 = cluster_1[:,5].sum(axis=0)#----------adding all the particalura coloumn which is cost of particular cluster
    sum_cluster_2 = cluster_2[:,6].sum(axis=0)
    sum_cluster_3 = cluster_3[:,7].sum(axis=0)#-------adding all the minimum cost of particualr clusters
    sum_cluster_4 = cluster_4[:,8].sum(axis=0)
    total_cost_cluster = sum_cluster_1 + sum_cluster_2 + sum_cluster_3 +sum_cluster_4
    print(total_cost_cluster, l+1)  
    #print(mediod)
    
    difference_cost= total_cost_cluster - old_cost
    if (difference_cost<=0):#------------bad cost
        non_mediod = customer_new[np.random.choice(customer_new.shape[0], 1, replace=False), :]#---------for cluster4
        non_mediod = np.delete(non_mediod, np.s_[4:9], axis=1) 
        mediod[3]= non_mediod
        old_cost = total_cost_cluster
        #print("difference is", + difference_cost)
    cluster_4_old = cluster_4
    old_cost = total_cost_cluster
    
    difference_cost= total_cost_cluster - old_cost
    if (difference_cost<=0):#------------bad cost
        non_mediod = customer_new[np.random.choice(customer_new.shape[0], 1, replace=False), :]#---------for cluster3
        non_mediod = np.delete(non_mediod, np.s_[4:9], axis=1) 
        mediod[2]= non_mediod
        old_cost = total_cost_cluster
        #print("difference is", + difference_cost)
    cluster_3_old = cluster_3
    old_cost = total_cost_cluster
    
    
    if (difference_cost<=0):#------------bad cost
        non_mediod = customer_new[np.random.choice(customer_new.shape[0], 1, replace=False), :]#---------for cluster2
        non_mediod = np.delete(non_mediod, np.s_[4:9], axis=1) 
        mediod[1]= non_mediod
        old_cost = total_cost_cluster
        #print("difference is", + difference_cost)
    cluster_2_old = cluster_2
    old_cost = total_cost_cluster
    
    if (difference_cost<=0):#------------bad cost
        non_mediod = customer_new[np.random.choice(customer_new.shape[0], 1, replace=False), :]#---------for cluster 1
        non_mediod = np.delete(non_mediod, np.s_[4:9], axis=1) 
        mediod[0]= non_mediod
        old_cost = total_cost_cluster
        #print("difference is", + difference_cost)
    cluster_1_old = cluster_1
    old_cost = total_cost_cluster
# Out:
# lenth is 20
# 8798 1
# lenth is 109
# 14967 2
# lenth is 92
# 12373 3
# lenth is 22
# 15275 4
# lenth is 65
# 14690 5
# lenth is 52
# 14646 6
# lenth is 24
# 15204 7
# lenth is 33
# 14589 8
# lenth is 16
# 14196 9
# lenth is 42
# 14300 10
# lenth is 34
# 14313 11
# lenth is 29
# 14466 12
# lenth is 59
# 14508 13
# lenth is 60
# 17924 14
# lenth is 70
# 14097 15
# lenth is 72
# 14892 16
# lenth is 57
# 13458 17
# lenth is 82
# 14329 18
# lenth is 50
# 14387 19
# lenth is 72
# 14577 20
# lenth is 32
# 15026 21
# lenth is 48
# 14209 22
# lenth is 72
# 16141 23
# lenth is 48
# 14251 24
# lenth is 16
# 15110 25
# lenth is 49
# 14128 26
# lenth is 79
# 18004 27
# lenth is 39
# 14304 28
# lenth is 44
# 13799 29
# lenth is 15
# 15428 30
# lenth is 47
# 14340 31
# lenth is 61
# 13641 32
# lenth is 112
# 24568 33
# lenth is 37
# 14511 34
# lenth is 29
# 15101 35
# lenth is 19
# 15495 36
# lenth is 28
# 14216 37
# lenth is 60
# 16067 38
# lenth is 25
# 14630 39
# lenth is 67
# 13787 40
# lenth is 42
# 16297 41
# lenth is 6
# 15154 42
# lenth is 44
# 13541 43
# lenth is 31
# 14545 44
# lenth is 60
# 14389 45
# lenth is 42
# 14179 46
# lenth is 60
# 14119 47
# lenth is 48
# 17271 48
# lenth is 13
# 16175 49
# lenth is 71
# 19101 50
# lenth is 75
# 15062 51
# lenth is 95
# 14776 52
# lenth is 51
# 13753 53
# lenth is 38
# 16039 54
# lenth is 33
# 14592 55
# lenth is 15
# 16012 56
# lenth is 35
# 14578 57
# lenth is 22
# 15196 58
# lenth is 51
# 14217 59
# lenth is 29
# 14205 60
# lenth is 80
# 14172 61
# lenth is 32
# 14845 62
# lenth is 123
# 23713 63
# lenth is 125
# 15814 64
# lenth is 19
# 14003 65
# lenth is 19
# 17136 66
# lenth is 38
# 14439 67
# lenth is 69
# 14881 68
# lenth is 76
# 14193 69
# lenth is 39
# 13713 70
# lenth is 22
# 14551 71
# lenth is 123
# 14508 72
# lenth is 109
# 15004 73
# lenth is 87
# 15563 74
# lenth is 40
# 14749 75
# lenth is 47
# 15038 76
# lenth is 37
# 14451 77
# lenth is 51
# 14383 78
# lenth is 7
# 15270 79
# lenth is 13
# 14753 80
# lenth is 55
# 19696 81
# lenth is 69
# 15386 82
# lenth is 104
# 14994 83
# lenth is 19
# 15099 84
# lenth is 47
# 14536 85
# lenth is 62
# 15849 86
# lenth is 59
# 13753 87
# lenth is 55
# 14387 88
# lenth is 27
# 14430 89
# lenth is 36
# 15188 90
# lenth is 7
# 16072 91
# lenth is 61
# 14680 92
# lenth is 63
# 14424 93
# lenth is 97
# 14697 94
# lenth is 36
# 14748 95
# lenth is 95
# 14347 96
# lenth is 71
# 13426 97
# lenth is 32
# 13731 98
# lenth is 45
# 13520 99
# lenth is 47
# 13693 100
# lenth is 46
# 14256 101
# lenth is 52
# 14376 102
# lenth is 65
# 13456 103
# lenth is 35
# 14265 104
# lenth is 34
# 14519 105
# lenth is 36
# 13816 106
# lenth is 78
# 14280 107
# lenth is 38
# 23275 108
# lenth is 30
# 14277 109
# lenth is 63
# 15197 110
# lenth is 17
# 14598 111
# lenth is 15
# 15039 112
# lenth is 80
# 15674 113
# lenth is 66
# 14627 114
# lenth is 52
# 13828 115
# lenth is 55
# 19090 116
# lenth is 64
# 13563 117
# lenth is 52
# 15813 118
# lenth is 16
# 14889 119
# lenth is 77
# 14791 120
# lenth is 25
# 14719 121
# lenth is 128
# 15379 122
# lenth is 98
# 14467 123
# lenth is 70
# 14186 124
# lenth is 55
# 14191 125
# lenth is 61
# 14672 126
# lenth is 67
# 16414 127
# lenth is 56
# 15374 128
# lenth is 91
# 15020 129
# lenth is 14
# 14127 130
# lenth is 39
# 20771 131
# lenth is 45
# 14354 132
# lenth is 57
# 13869 133
# lenth is 30
# 14985 134
# lenth is 144
# 18160 135
# lenth is 53
# 15726 136
# lenth is 13
# 14236 137
# lenth is 60
# 14439 138
# lenth is 23
# 14683 139
# lenth is 37
# 14049 140
# lenth is 25
# 20030 141
# lenth is 7
# 15284 142
# lenth is 16
# 14531 143
# lenth is 26
# 16287 144
# lenth is 29
# 14818 145
# lenth is 45
# 13922 146
# lenth is 44
# 14923 147
# lenth is 57
# 13386 148
# lenth is 22
# 14200 149
# lenth is 41
# 13802 150
# lenth is 84
# 14629 151
# lenth is 32
# 14368 152
# lenth is 41
# 13968 153
# lenth is 34
# 14368 154
# lenth is 46
# 14113 155
# lenth is 31
# 13827 156
# lenth is 57
# 15012 157
# lenth is 90
# 14482 158
# lenth is 28
# 14499 159
# lenth is 31
# 13879 160
# lenth is 44
# 14513 161
# lenth is 74
# 13883 162
# lenth is 78
# 14606 163
# lenth is 65
# 14162 164
# lenth is 54
# 15290 165
# lenth is 128
# 15731 166
# lenth is 26
# 14574 167
# lenth is 85
# 14511 168
# lenth is 54
# 13771 169
# lenth is 42
# 15519 170
# lenth is 89
# 13810 171
# lenth is 60
# 14487 172
# lenth is 60
# 14802 173
# lenth is 68
# 14488 174
# lenth is 6
# 16572 175
# lenth is 5
# 14175 176
# lenth is 84
# 14288 177
# lenth is 92
# 16690 178
# lenth is 101
# 14619 179
# lenth is 19
# 14398 180
# lenth is 46
# 14783 181
# lenth is 52
# 14191 182
# lenth is 19
# 22629 183
# lenth is 60
# 14475 184
# lenth is 15
# 15841 185
# lenth is 7
# 14458 186
# lenth is 91
# 16450 187
# lenth is 83
# 13686 188
# lenth is 43
# 15785 189
# lenth is 57
# 14442 190
# lenth is 92
# 15056 191
# lenth is 57
# 14004 192
# lenth is 26
# 15866 193
# lenth is 22
# 14720 194
# lenth is 42
# 14273 195
# lenth is 23
# 16802 196

# %% [markdown]
# ## New coloumn added below for assigned cluster

# %%
dataset_1
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      cost_1  cost_2  cost_3  cost_4 Assigned_cluster
# 1       139     133     127     133        Cluster_3
# 2        64      56      52      56        Cluster_3
# 4        94     100      74     100        Cluster_3
# 5       131     127     119     127        Cluster_3
# 6        63      69      35      69        Cluster_3
# ..      ...     ...     ...     ...              ...
# 195     140     150     190     150        Cluster_1
# 196     105     115     135     115        Cluster_1
# 197     138     148     194     148        Cluster_1
# 198      93     103     149     103        Cluster_1
# 199     156     166     216     166        Cluster_1
#
# [196 rows x 10 columns]

# %% [markdown]
# ## Calculating silhoutte width for each clusters

# %%
distance_age_k2 = []
distance_income_k2 = []
distance_score_k2 = []
total_distance_k2 = []
distance_sil = []
average_sill = []
total=0
q=0
w=0
e=0
a=0

total=0

for i in range(len(cluster_1)):
    for j in range(len(cluster_1)):#------------calcualting distance
        q = manhattan_distance(cluster_1[i,2],cluster_1[j,2])
        #distance_age_k2.append(q)
        w = manhattan_distance(cluster_1[i,3],cluster_1[j,3])
        #distance_income_k2.append(w)
        e = manhattan_distance(cluster_1[i,4],cluster_1[j,4])
        #distance_score.append(e)
        total = q+w+e
        distance_sil.append(total/3)
    a_sil = sum(distance_sil)/len(cluster_1)
    #print(a_sil)
    distance_sil.clear()
    

    cluster_min=0
    
    distance_age_k2 = []
    distance_income_k2 = []
    distance_score_k2 = []
    total_distance_k2 = []
    distance_sil = []
    q=0
    w=0
    e=0
    a=0

    total=0
    n=0#--------------for cluster 1
    for j in range(len(mediod)):#------------calcualting nearest cluster
        q = manhattan_distance(mediod[n,2],mediod[j,2])
        #distance_age_k2.append(q)
        w = manhattan_distance(mediod[n,3],mediod[j,3])
        #distance_income_k2.append(w)
        e = manhattan_distance(mediod[n,4],mediod[j,4])
        #distance_score.append(e)
        total = q+w+e
        distance_sil.append(total)
    #print(distance_sil)
    index = [i for i in range(0,4)]
    #print(index)
    index=np.asarray(index)
    distance_sil= np.asarray(distance_sil)
    distance_sil.transpose
    #print(distance_sil)
    distance_sil = np.column_stack((index,distance_sil))
    #print(distance_sil[:,1])
    minval = np.min(distance_sil[:,1][np.nonzero(distance_sil[:,1])])
    #print(minval)
    for b in range(len(distance_sil)):
        if (minval == distance_sil[b,1]):
            cluster_min = b
            #print(cluster_min)




    #---------now find the value of b
    if (cluster_min == 0):
            selected_cluster= cluster_1
    if (cluster_min == 1):
            selected_cluster= cluster_2
    if (cluster_min == 2):
            selected_cluster= cluster_3
    if (cluster_min == 3):
            selected_cluster= cluster_4
    if (cluster_min == 4):
            selected_cluster= cluster_5

    distance_age_k2 = []
    distance_b= []
    distance_income_k2 = []
    distance_score_k2 = []
    total_distance_k2 = []
    distance_sil = []
    q=0
    w=0
    e=0
    a=0
    s=0

    total=0
    
    for j in range(len(selected_cluster)):#------------calcualting distance


        q = manhattan_distance(cluster_1[i,2],selected_cluster[j,2])
        #distance_age_k2.append(q)
        w = manhattan_distance(cluster_1[i,3],selected_cluster[j,3])
        #distance_income_k2.append(w)
        e = manhattan_distance(cluster_1[i,4],selected_cluster[j,4])
        #distance_score.append(e)
        total = q+w+e
        distance_b.append(total)
   # print(min(distance_b))
    b = min(distance_b)
    maxi = max(b, a_sil)
    #print("a is", + maxi)
    d = b - a_sil
    sill = ((b - a_sil) / maxi)#------------silhoutte widht formulae
    print("Silhoutte width for each point in cluster 1", +  sill)
    
    average_sill.append(sill)
s_c1 = sum(average_sill)/len(average_sill)
print("Average silhoutee width for cluster 1", + s_c1)
# Out:
# Silhoutte width for each point in cluster 1 -1.0
# Silhoutte width for each point in cluster 1 -0.5335978180014878
# Silhoutte width for each point in cluster 1 -1.0
# Silhoutte width for each point in cluster 1 -0.0724852071005914
# Silhoutte width for each point in cluster 1 0.1869328493647912
# Silhoutte width for each point in cluster 1 0.2516506319562347
# Silhoutte width for each point in cluster 1 -0.23999999999999988
# Silhoutte width for each point in cluster 1 -0.271177410761854
# Silhoutte width for each point in cluster 1 -0.4522156967431928
# Silhoutte width for each point in cluster 1 -0.020057306590257586
# Silhoutte width for each point in cluster 1 -0.7503649635036496
# Silhoutte width for each point in cluster 1 0.15687770150012664
# Silhoutte width for each point in cluster 1 0.10749094959621243
# Silhoutte width for each point in cluster 1 -0.03480714957667002
# Silhoutte width for each point in cluster 1 0.36200716845878156
# Silhoutte width for each point in cluster 1 0.0019493177387916757
# Silhoutte width for each point in cluster 1 0.42672858617131065
# Silhoutte width for each point in cluster 1 0.31600606454407615
# Silhoutte width for each point in cluster 1 0.10497076023391845
# Silhoutte width for each point in cluster 1 -0.3200795228628231
# Silhoutte width for each point in cluster 1 -1.0
# Silhoutte width for each point in cluster 1 0.34565580618212216
# Silhoutte width for each point in cluster 1 -0.7259615384615385
# Silhoutte width for each point in cluster 1 0.30885856616850765
# Silhoutte width for each point in cluster 1 0.40935672514619864
# Silhoutte width for each point in cluster 1 0.5452091767881242
# Silhoutte width for each point in cluster 1 -0.6158536585365855
# Silhoutte width for each point in cluster 1 0.40614978305980026
# Silhoutte width for each point in cluster 1 0.513873335821824
# Silhoutte width for each point in cluster 1 0.4590643274853801
# Silhoutte width for each point in cluster 1 0.5038986354775827
# Silhoutte width for each point in cluster 1 0.5331185105621196
# Silhoutte width for each point in cluster 1 0.487639553429027
# Silhoutte width for each point in cluster 1 0.06562703053931113
# Silhoutte width for each point in cluster 1 0.5117608836907084
# Silhoutte width for each point in cluster 1 0.5095621937727203
# Silhoutte width for each point in cluster 1 0.47468671679197993
# Silhoutte width for each point in cluster 1 -0.19039567128846793
# Silhoutte width for each point in cluster 1 0.20607073238652196
# Silhoutte width for each point in cluster 1 0.4768911526127146
# Silhoutte width for each point in cluster 1 0.5427398282941395
# Silhoutte width for each point in cluster 1 -0.02033801203093692
# Silhoutte width for each point in cluster 1 0.5602896129211921
# Silhoutte width for each point in cluster 1 0.5000835421888056
# Silhoutte width for each point in cluster 1 0.5653396311291046
# Silhoutte width for each point in cluster 1 0.40497076023391826
# Silhoutte width for each point in cluster 1 0.6302387914230019
# Silhoutte width for each point in cluster 1 0.2584064327485379
# Silhoutte width for each point in cluster 1 0.6364721327127341
# Silhoutte width for each point in cluster 1 0.009849184364419727
# Silhoutte width for each point in cluster 1 0.5420129270544782
# Silhoutte width for each point in cluster 1 0.5221956406166931
# Silhoutte width for each point in cluster 1 0.0856950067476383
# Silhoutte width for each point in cluster 1 0.5835421888053469
# Silhoutte width for each point in cluster 1 0.6183235867446394
# Silhoutte width for each point in cluster 1 0.2989953516269308
# Silhoutte width for each point in cluster 1 0.5249173658784644
# Silhoutte width for each point in cluster 1 0.14736842105263132
# Silhoutte width for each point in cluster 1 0.603256507281275
# Silhoutte width for each point in cluster 1 -0.5284532464276761
# Silhoutte width for each point in cluster 1 0.5025584795321635
# Silhoutte width for each point in cluster 1 0.5981806367771278
# Silhoutte width for each point in cluster 1 0.625108871469454
# Silhoutte width for each point in cluster 1 0.3791737408036221
# Silhoutte width for each point in cluster 1 0.5979532163742689
# Silhoutte width for each point in cluster 1 0.40417710944026747
# Silhoutte width for each point in cluster 1 0.6532857567647934
# Silhoutte width for each point in cluster 1 0.4789323736692159
# Silhoutte width for each point in cluster 1 0.6809732664995823
# Silhoutte width for each point in cluster 1 0.4282856263465681
# Silhoutte width for each point in cluster 1 0.5265700483091786
# Silhoutte width for each point in cluster 1 -0.001168224299065312
# Silhoutte width for each point in cluster 1 0.6261988304093566
# Silhoutte width for each point in cluster 1 -0.12184873949579837
# Silhoutte width for each point in cluster 1 0.6038986354775829
# Silhoutte width for each point in cluster 1 0.6362781954887218
# Silhoutte width for each point in cluster 1 0.6360446570972886
# Silhoutte width for each point in cluster 1 0.5611741772732486
# Silhoutte width for each point in cluster 1 0.6235380116959063
# Silhoutte width for each point in cluster 1 0.6922027290448344
# Silhoutte width for each point in cluster 1 0.5112199102407179
# Silhoutte width for each point in cluster 1 0.6098440545808969
# Silhoutte width for each point in cluster 1 0.570240415854451
# Silhoutte width for each point in cluster 1 0.6198830409356726
# Silhoutte width for each point in cluster 1 0.3535505430242272
# Silhoutte width for each point in cluster 1 0.6356941737058697
# Silhoutte width for each point in cluster 1 0.16812865497075993
# Silhoutte width for each point in cluster 1 0.6305243984277635
# Silhoutte width for each point in cluster 1 0.48026315789473667
# Silhoutte width for each point in cluster 1 0.6507262780607432
# Silhoutte width for each point in cluster 1 0.5352965747702588
# Silhoutte width for each point in cluster 1 0.5980750487329435
# Silhoutte width for each point in cluster 1 0.5475985044578662
# Silhoutte width for each point in cluster 1 0.6589267285861712
# Silhoutte width for each point in cluster 1 0.6454930429522081
# Silhoutte width for each point in cluster 1 0.6818072578707043
# Silhoutte width for each point in cluster 1 0.5331384015594542
# Silhoutte width for each point in cluster 1 0.6456479362657851
# Silhoutte width for each point in cluster 1 0.6445060018467221
# Silhoutte width for each point in cluster 1 0.6232131254061078
# Silhoutte width for each point in cluster 1 0.6513355460723883
# Silhoutte width for each point in cluster 1 0.6427955133735977
# Silhoutte width for each point in cluster 1 0.5485588972431076
# Silhoutte width for each point in cluster 1 0.7103870788081313
# Silhoutte width for each point in cluster 1 0.5687400318979267
# Silhoutte width for each point in cluster 1 0.6812005503955968
# Silhoutte width for each point in cluster 1 0.3790428452082589
# Silhoutte width for each point in cluster 1 0.6807667316439245
# Silhoutte width for each point in cluster 1 0.5979907032538611
# Silhoutte width for each point in cluster 1 0.7138680033416874
# Silhoutte width for each point in cluster 1 0.6767450541246733
# Silhoutte width for each point in cluster 1 0.6963937621832361
# Silhoutte width for each point in cluster 1 0.5698188560832979
# Silhoutte width for each point in cluster 1 0.6952908587257617
# Average silhoutee width for cluster 1 0.3440278592157451

# %%
distance_age_k2 = []
distance_income_k2 = []
distance_score_k2 = []
total_distance_k2 = []
distance_sil = []
average_sill = []
total=0
q=0
w=0
e=0
a=0

total=0

for i in range(len(cluster_2)):
    for j in range(len(cluster_2)):#------------calcualting distance
        q = manhattan_distance(cluster_2[i,2],cluster_2[j,2])
        #distance_age_k2.append(q)
        w = manhattan_distance(cluster_2[i,3],cluster_2[j,3])
        #distance_income_k2.append(w)
        e = manhattan_distance(cluster_2[i,4],cluster_2[j,4])
        #distance_score.append(e)
        total = q+w+e
        distance_sil.append(total/3)
    a_sil = sum(distance_sil)/len(cluster_2)
    #print(a_sil)
    distance_sil.clear()
    

    
    cluster_min=0
    
    distance_age_k2 = []
    distance_income_k2 = []
    distance_score_k2 = []
    total_distance_k2 = []
    distance_sil = []
    q=0
    w=0
    e=0
    a=0

    total=0
    n=1#--------------for cluster 2
    for j in range(len(mediod)):#------------calcualting nearest cluster
        q = manhattan_distance(mediod[n,2],mediod[j,2])
        #distance_age_k2.append(q)
        w = manhattan_distance(mediod[n,3],mediod[j,3])
        #distance_income_k2.append(w)
        e = manhattan_distance(mediod[n,4],mediod[j,4])
        #distance_score.append(e)
        total = q+w+e
        distance_sil.append(total)
    #print(distance_sil)
    index = [i for i in range(0,4)]
    #print(index)
    index=np.asarray(index)
    distance_sil= np.asarray(distance_sil)
    distance_sil.transpose
    #print(distance_sil)
    distance_sil = np.column_stack((index,distance_sil))
    #print(distance_sil[:,1])
    minval = np.min(distance_sil[:,1][np.nonzero(distance_sil[:,1])])
    #print(minval)
    for b in range(len(distance_sil)):
        if (minval == distance_sil[b,1]):
            cluster_min = b
            #print(cluster_min)




    #---------now find the value of b
    if (cluster_min == 0):
            selected_cluster= cluster_1
    if (cluster_min == 1):
            selected_cluster= cluster_2
    if (cluster_min == 2):
            selected_cluster= cluster_3
    if (cluster_min == 3):
            selected_cluster= cluster_4
    if (cluster_min == 4):
            selected_cluster= cluster_5

    distance_age_k2 = []
    distance_b= []
    distance_income_k2 = []
    distance_score_k2 = []
    total_distance_k2 = []
    distance_sil = []
    q=0
    w=0
    e=0
    a=0
    s=0

    total=0
    
    for j in range(len(selected_cluster)):#------------calcualting distance


        q = manhattan_distance(cluster_2[i,2],selected_cluster[j,2])
        #distance_age_k2.append(q)
        w = manhattan_distance(cluster_2[i,3],selected_cluster[j,3])
        #distance_income_k2.append(w)
        e = manhattan_distance(cluster_2[i,4],selected_cluster[j,4])
        #distance_score.append(e)
        total = q+w+e
        distance_b.append(total)
   # print(min(distance_b))
    b = min(distance_b)
    maxi = max(b, a_sil)
    #print("a is", + maxi)
    d = b - a_sil
    sill = ((b - a_sil) / maxi)#------------silhoutte widht formulae
    print("Silhoutte width for each point in cluster 2", +  sill)
    
    average_sill.append(sill)
s_c2 = sum(average_sill)/len(average_sill)
print("Average silhoutee width for cluster 1", + s_c2)
# Out:
# Silhoutte width for each point in cluster 2 -0.3568575233022636
# Silhoutte width for each point in cluster 2 -0.4079563182527301
# Silhoutte width for each point in cluster 2 -0.3721565059144674
# Silhoutte width for each point in cluster 2 -0.28075052119527466
# Silhoutte width for each point in cluster 2 0.2654462242562928
# Silhoutte width for each point in cluster 2 0.664796633941094
# Silhoutte width for each point in cluster 2 0.6837169650468883
# Silhoutte width for each point in cluster 2 0.6807202459376374
# Silhoutte width for each point in cluster 2 0.6501035196687371
# Silhoutte width for each point in cluster 2 0.7221532091097308
# Silhoutte width for each point in cluster 2 0.7271221532091097
# Silhoutte width for each point in cluster 2 0.7081864473168822
# Silhoutte width for each point in cluster 2 0.7000439174352219
# Silhoutte width for each point in cluster 2 0.7450058754406581
# Silhoutte width for each point in cluster 2 0.6824016563146998
# Silhoutte width for each point in cluster 2 0.7061191626409017
# Silhoutte width for each point in cluster 2 0.7785642062689586
# Silhoutte width for each point in cluster 2 0.7391304347826086
# Silhoutte width for each point in cluster 2 0.7600269632625548
# Silhoutte width for each point in cluster 2 0.7578649699540473
# Silhoutte width for each point in cluster 2 0.6179410294852573
# Silhoutte width for each point in cluster 2 0.6655164481251439
# Silhoutte width for each point in cluster 2 0.6331386545533203
# Average silhoutee width for cluster 1 0.4987077325254352

# %%
distance_age_k2 = []
distance_income_k2 = []
distance_score_k2 = []
total_distance_k2 = []
distance_sil = []
average_sill = []
total=0
q=0
w=0
e=0
a=0

total=0

for i in range(len(cluster_3)):
    for j in range(len(cluster_3)):#------------calcualting distance
        q = manhattan_distance(cluster_3[i,2],cluster_3[j,2])
        #distance_age_k2.append(q)
        w = manhattan_distance(cluster_3[i,3],cluster_3[j,3])
        #distance_income_k2.append(w)
        e = manhattan_distance(cluster_3[i,4],cluster_3[j,4])
        #distance_score.append(e)
        total = q+w+e
        distance_sil.append(total/3)
    a_sil = sum(distance_sil)/len(cluster_3)
    #print(a_sil)
    distance_sil.clear()
    

    cluster_min=0
    
    distance_age_k2 = []
    distance_income_k2 = []
    distance_score_k2 = []
    total_distance_k2 = []
    distance_sil = []
    q=0
    w=0
    e=0
    a=0

    total=0
    n=2#--------------for cluster 2
    for j in range(len(mediod)):#------------calcualting nearest cluster
        q = manhattan_distance(mediod[n,2],mediod[j,2])
        #distance_age_k2.append(q)
        w = manhattan_distance(mediod[n,3],mediod[j,3])
        #distance_income_k2.append(w)
        e = manhattan_distance(mediod[n,4],mediod[j,4])
        #distance_score.append(e)
        total = q+w+e
        distance_sil.append(total)
    #print(distance_sil)
    index = [i for i in range(0,4)]
    #print(index)
    index=np.asarray(index)
    distance_sil= np.asarray(distance_sil)
    distance_sil.transpose
    #print(distance_sil)
    distance_sil = np.column_stack((index,distance_sil))
    #print(distance_sil[:,1])
    minval = np.min(distance_sil[:,1][np.nonzero(distance_sil[:,1])])
    #print(minval)
    for b in range(len(distance_sil)):
        if (minval == distance_sil[b,1]):
            cluster_min = b
            #print(cluster_min)




    #---------now find the value of b
    if (cluster_min == 0):
            selected_cluster= cluster_1
    if (cluster_min == 1):
            selected_cluster= cluster_2
    if (cluster_min == 2):
            selected_cluster= cluster_3
    if (cluster_min == 3):
            selected_cluster= cluster_4
    if (cluster_min == 4):
            selected_cluster= cluster_5

    distance_age_k2 = []
    distance_b= []
    distance_income_k2 = []
    distance_score_k2 = []
    total_distance_k2 = []
    distance_sil = []
    q=0
    w=0
    e=0
    a=0
    s=0

    total=0
    
    for j in range(len(selected_cluster)):#------------calcualting distance


        q = manhattan_distance(cluster_3[i,2],selected_cluster[j,2])
        #distance_age_k2.append(q)
        w = manhattan_distance(cluster_3[i,3],selected_cluster[j,3])
        #distance_income_k2.append(w)
        e = manhattan_distance(cluster_3[i,4],selected_cluster[j,4])
        #distance_score.append(e)
        total = q+w+e
        distance_b.append(total)
   # print(min(distance_b))
    b = min(distance_b)
    maxi = max(b, a_sil)
    #print("a is", + maxi)
    d = b - a_sil
    sill = ((b - a_sil) / maxi)#------------silhoutte widht formulae
    print("Silhoutte width for each point in cluster 3", +  sill)
    
    average_sill.append(sill)
s_c3 = sum(average_sill)/len(average_sill)
print("Average silhoutee width for cluster 1", + s_c3)
# Out:
# Silhoutte width for each point in cluster 3 -0.3239095315024233
# Silhoutte width for each point in cluster 3 0.5066740823136819
# Silhoutte width for each point in cluster 3 0.6517323775388292
# Silhoutte width for each point in cluster 3 -0.09828118113706467
# Silhoutte width for each point in cluster 3 0.6527336059366954
# Silhoutte width for each point in cluster 3 -0.24081632653061238
# Silhoutte width for each point in cluster 3 0.733763440860215
# Silhoutte width for each point in cluster 3 0.3204994797086367
# Silhoutte width for each point in cluster 3 0.7728871470204
# Silhoutte width for each point in cluster 3 0.24876489392618423
# Silhoutte width for each point in cluster 3 0.7764976958525346
# Silhoutte width for each point in cluster 3 -0.1432519576232151
# Silhoutte width for each point in cluster 3 0.7056630824372759
# Silhoutte width for each point in cluster 3 -0.3436259373621526
# Silhoutte width for each point in cluster 3 0.6991069801348643
# Silhoutte width for each point in cluster 3 0.042075736325385735
# Silhoutte width for each point in cluster 3 0.16431451612903247
# Silhoutte width for each point in cluster 3 0.691436251920123
# Silhoutte width for each point in cluster 3 -0.06953476738369176
# Silhoutte width for each point in cluster 3 0.6913687881429816
# Silhoutte width for each point in cluster 3 0.1978494623655915
# Silhoutte width for each point in cluster 3 0.7592662871600252
# Silhoutte width for each point in cluster 3 -0.37583892617449666
# Silhoutte width for each point in cluster 3 0.7457402812241521
# Silhoutte width for each point in cluster 3 0.3502894954507857
# Silhoutte width for each point in cluster 3 0.7173835125448029
# Silhoutte width for each point in cluster 3 -0.5238907849829353
# Silhoutte width for each point in cluster 3 0.7144137224782385
# Silhoutte width for each point in cluster 3 -0.5450097847358122
# Silhoutte width for each point in cluster 3 0.6903516419645452
# Silhoutte width for each point in cluster 3 0.734910394265233
# Silhoutte width for each point in cluster 3 0.7218125960061444
# Silhoutte width for each point in cluster 3 -0.24060968971148616
# Silhoutte width for each point in cluster 3 0.6565226212213431
# Silhoutte width for each point in cluster 3 0.7456690561529271
# Silhoutte width for each point in cluster 3 0.7019679448163928
# Silhoutte width for each point in cluster 3 0.7235518557058619
# Silhoutte width for each point in cluster 3 0.5864574251671024
# Silhoutte width for each point in cluster 3 0.5899447834931707
# Silhoutte width for each point in cluster 3 0.60752688172043
# Silhoutte width for each point in cluster 3 0.6522482893450635
# Silhoutte width for each point in cluster 3 0.638909727431858
# Silhoutte width for each point in cluster 3 0.6046319272125723
# Silhoutte width for each point in cluster 3 0.6916975145425702
# Silhoutte width for each point in cluster 3 0.630407601900475
# Silhoutte width for each point in cluster 3 0.619313482216708
# Silhoutte width for each point in cluster 3 0.6327219059666874
# Silhoutte width for each point in cluster 3 0.5289725209080047
# Silhoutte width for each point in cluster 3 0.6190803019903911
# Silhoutte width for each point in cluster 3 0.42511520737327185
# Silhoutte width for each point in cluster 3 0.6527859237536657
# Silhoutte width for each point in cluster 3 0.6250497809637596
# Silhoutte width for each point in cluster 3 0.5684776457272213
# Silhoutte width for each point in cluster 3 0.5984848484848485
# Silhoutte width for each point in cluster 3 0.5887096774193546
# Silhoutte width for each point in cluster 3 0.5481248360870705
# Silhoutte width for each point in cluster 3 0.4952380952380953
# Silhoutte width for each point in cluster 3 0.4786482334869429
# Silhoutte width for each point in cluster 3 0.6025641025641024
# Silhoutte width for each point in cluster 3 0.4384321886923343
# Silhoutte width for each point in cluster 3 0.456989247311828
# Silhoutte width for each point in cluster 3 0.5315860215053763
# Average silhoutee width for cluster 1 0.44555800375744997

# %%
distance_age_k2 = []
distance_income_k2 = []
distance_score_k2 = []
total_distance_k2 = []
distance_sil = []
average_sill = []
total=0
q=0
w=0
e=0
a=0

total=0

for i in range(len(cluster_4)):
    for j in range(len(cluster_4)):#------------calcualting distance
        q = manhattan_distance(cluster_4[i,2],cluster_4[j,2])
        #distance_age_k2.append(q)
        w = manhattan_distance(cluster_4[i,3],cluster_4[j,3])
        #distance_income_k2.append(w)
        e = manhattan_distance(cluster_4[i,4],cluster_4[j,4])
        #distance_score.append(e)
        total = q+w+e
        distance_sil.append(total/3)
    a_sil = sum(distance_sil)/len(cluster_4)
    #print(a_sil)
    distance_sil.clear()

    
    
    
    
    cluster_min=0
    
    distance_age_k2 = []
    distance_income_k2 = []
    distance_score_k2 = []
    total_distance_k2 = []
    distance_sil = []
    q=0
    w=0
    e=0
    a=0

    total=0
    n=3#--------------for cluster 4
    for j in range(len(mediod)):#------------calcualting nearest cluster
        q = manhattan_distance(mediod[n,2],mediod[j,2])
        #distance_age_k2.append(q)
        w = manhattan_distance(mediod[n,3],mediod[j,3])
        #distance_income_k2.append(w)
        e = manhattan_distance(mediod[n,4],mediod[j,4])
        #distance_score.append(e)
        total = q+w+e
        distance_sil.append(total)
    #print(distance_sil)
    index = [i for i in range(0,4)]
    #print(index)
    index=np.asarray(index)
    distance_sil= np.asarray(distance_sil)
    distance_sil.transpose
    #print(distance_sil)
    distance_sil = np.column_stack((index,distance_sil))
    #print(distance_sil[:,1])
    minval = np.min(distance_sil[:,1][np.nonzero(distance_sil[:,1])])
    #print(minval)
    for b in range(len(distance_sil)):
        if (minval == distance_sil[b,1]):
            cluster_min = b
            #print(cluster_min)




    #---------now find the value of b
    if (cluster_min == 0):
            selected_cluster= cluster_1
    if (cluster_min == 1):
            selected_cluster= cluster_2
    if (cluster_min == 2):
            selected_cluster= cluster_3
    if (cluster_min == 3):
            selected_cluster= cluster_4
    if (cluster_min == 4):
            selected_cluster= cluster_5

    distance_age_k2 = []
    distance_b= []
    distance_income_k2 = []
    distance_score_k2 = []
    total_distance_k2 = []
    distance_sil = []
    q=0
    w=0
    e=0
    a=0
    s=0

    total=0
    
    for j in range(len(selected_cluster)):#------------calcualting distance


        q = manhattan_distance(cluster_4[i,2],selected_cluster[j,2])
        #distance_age_k2.append(q)
        w = manhattan_distance(cluster_4[i,3],selected_cluster[j,3])
        #distance_income_k2.append(w)
        e = manhattan_distance(cluster_4[i,4],selected_cluster[j,4])
        #distance_score.append(e)
        total = q+w+e
        distance_b.append(total)
   # print(min(distance_b))
    b = min(distance_b)
    maxi = max(b, a_sil)
    #print("a is", + maxi)
    d = b - a_sil
    sill = ((b - a_sil) / maxi)#------------silhoutte widht formulae
    print("Silhoutte width for each point in cluster 4", +  sill)
    
    average_sill.append(sill)
s_c4 = sum(average_sill)/len(average_sill)
print("Average silhoutee width for cluster 1", + s_c4)
# Out:
# Silhoutte width for each point in cluster 4 -0.4946737683089214
# Silhoutte width for each point in cluster 4 0.02212051868802446
# Silhoutte width for each point in cluster 4 0.0045289855072467855
# Silhoutte width for each point in cluster 4 -1.0
# Silhoutte width for each point in cluster 4 -1.0
# Silhoutte width for each point in cluster 4 0.13405797101449268
# Silhoutte width for each point in cluster 4 0.43401983218916856
# Silhoutte width for each point in cluster 4 0.41465378421900173
# Silhoutte width for each point in cluster 4 -0.489644970414201
# Silhoutte width for each point in cluster 4 -0.1773472429210134
# Silhoutte width for each point in cluster 4 -0.16236722306525045
# Silhoutte width for each point in cluster 4 0.3251811594202899
# Silhoutte width for each point in cluster 4 -1.0
# Silhoutte width for each point in cluster 4 -0.15207373271889385
# Silhoutte width for each point in cluster 4 0.07367149758454132
# Silhoutte width for each point in cluster 4 0.18617614269788177
# Silhoutte width for each point in cluster 4 -0.05479452054794526
# Silhoutte width for each point in cluster 4 0.3217391304347826
# Silhoutte width for each point in cluster 4 0.3120772946859904
# Silhoutte width for each point in cluster 4 0.17270531400966163
# Silhoutte width for each point in cluster 4 -0.27795945062132116
# Silhoutte width for each point in cluster 4 -0.4779917469050894
# Silhoutte width for each point in cluster 4 -0.30837264150943405
# Average silhoutee width for cluster 1 -0.13888233332873862

# %% [markdown]
# ## Average silhoutte width of dataset

# %%
Average_dataset = (s_c1+s_c2+s_c3+s_c4)/4
print("Average silhoutte width of dataset", + Average_dataset)
# Out:
# Average silhoutte width of dataset 0.28735281554247294

# %% [markdown]
# ## Plotting assigned clusters below

# %%
cluster_1 = np.asarray(cluster_1)
cluster_2 = np.asarray(cluster_2)
cluster_3 = np.asarray(cluster_3)
cluster_4 = np.asarray(cluster_4)
sns.set_style("white")
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
clusterX1 = cluster_1[:,2].tolist()
clusterY1 = cluster_1[:,3].tolist()
clusterZ1 = cluster_1[:,4].tolist()
clusterX2 = cluster_2[:,2].tolist()
clusterY2 = cluster_2[:,3].tolist()
clusterZ2 = cluster_2[:,4].tolist()
clusterX3 = cluster_3[:,2].tolist()
clusterY3 = cluster_3[:,3].tolist()
clusterZ3 = cluster_3[:,4].tolist()
clusterX4 = cluster_4[:,2].tolist()
clusterY4 = cluster_4[:,3].tolist()
clusterZ4 = cluster_4[:,4].tolist()
ax.scatter(clusterX1, clusterY1, clusterZ1, c='blue', s=60)
ax.scatter(clusterX2, clusterY2, clusterZ2, c='green', s=60)
ax.scatter(clusterX3, clusterY3, clusterZ3, c='orange', s=60)
ax.scatter(clusterX4, clusterY4, clusterZ4, c='purple', s=60)
ax.view_init(30, 185)
plt.xlabel("Age")
plt.ylabel("Annual Income (k$)")
ax.set_zlabel('Spending Score (1-100)')
plt.show()

# %% [markdown]
# ## Saving to csv file

# %%
export_csv = dataset_1.to_csv (r'W:\Lakehead Study material\Big data\Assignment 2\K mediod\Work directory\k_is_4\clusters_k.csv', index = None, header=True)
